# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd;
import numpy as np;
import seaborn as sns;
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/creditcard.csv')

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df.Amount.describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
data = df.sample(frac = 0.1,random_state = 2)

# %%
data.shape
# Out:
# (28481, 31)

# %%
data.plot(kind='scatter', x='Time', y='Amount') ;
plt.title("Time vs Amount")
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="Class", size=4) \
   .map(plt.scatter, "Time", "Amount") \
   .add_legend();
plt.title("Time vs Amount")
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(data, hue="Class", size=3,vars=["Time","Amount", "V6"]);
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
target = pd.value_counts(data['Class'], sort=True)
target.plot(kind = 'bar',rot=90)

# %%
f = data.loc[data["Class"] == 1];
#nf = data.loc[data["Class"] == 0];

f = plt.plot(f["Amount"], 'o',label = "f")
#nf = plt.plot(nf["Amount"],'o',label = "nf")
plt.title("Amount") 
plt.xlabel("Time")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %%
#f = data.loc[data["Class"] == 1];
nf = data.loc[data["Class"] == 0];

#f = plt.plot(f["Amount"], 'o',label = "f")
nf = plt.plot(nf["Amount"],'o',label = "nf")
plt.title("Amount") 
plt.xlabel("Time")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %%
g = sns.countplot(data['Class'])
g.set_xticklabels(['Not Fraud','Fraud'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
correlation = data.corr()
fig = plt.figure(figsize = (15, 15)) 
sns.heatmap(correlation, vmax = 1.0) 
plt.show()

# %%
x = data[['Amount','Time']]
y = data['Class']

# %%
x.shape
# Out:
# (28481, 2)

# %%
y.shape
# Out:
# (28481,)

# %%
x.Amount.mean()
# Out:
# 89.25250904111712

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x , y , test_size = 0.2,random_state=42)

# %%
from imblearn.over_sampling import SMOTE
m = SMOTE()
X, Y = m.fit_sample(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X,Y)
pred = rf.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 259734    0
# 126981    0
# 238613    0
# 91401     0
# 147936    0
#          ..
# 234845    0
# 142883    0
# 50103     0
# 137477    0
# 8307      0
# Name: Class, Length: 5697, dtype: int64

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97      5692
#            1       0.00      0.20      0.01         5
#
#     accuracy                           0.93      5697
#    macro avg       0.50      0.57      0.49      5697
# weighted avg       1.00      0.93      0.97      5697

# %%
cm = confusion_matrix(y_test,pred)
print(cm)
# Out:
# [[5321  371]
#  [   4    1]]

# %%
acc = accuracy_score(y_test,pred)
print("Accuracy score is:",acc)
# Out:
# Accuracy score is: 0.9341758820431806

# %%
import pickle

file = open('credit-card-fraud-detection.pkl', 'wb')

pickle.dump(rf, file)
